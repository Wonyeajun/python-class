# %%
import pandas as pd
GHG_data_pre = pd.read_csv("historical_emissions.csv")
CH4_data_pre = pd.read_csv("C:\Users\turing02\Downloads\20251102\historical_emissions(CH4)\historical_emissions.csv")
CO2_data_pre = pd.read_csv("C:\Users\turing02\Downloads\20251102\historical_emissions(CO2)\historical_emissions.csv")
N2O_data_pre = pd.read_csv("C:\Users\turing02\Downloads\20251102\historical_emissions(N2O)\historical_emissions.csv")

# %%
GHG_data_pre
# Out:
#       ISO      Country    Data source                      Sector      Gas  \
# 0     AFG  Afghanistan  Climate Watch        Total excluding LUCF  All GHG
# 1     AFG  Afghanistan  Climate Watch        Total including LUCF  All GHG
# 2     AFG  Afghanistan  Climate Watch                      Energy  All GHG
# 3     AFG  Afghanistan  Climate Watch        Industrial Processes  All GHG
# 4     AFG  Afghanistan  Climate Watch                 Agriculture  All GHG
# ...   ...          ...            ...                         ...      ...
# 2671  ZWE     Zimbabwe  Climate Watch                    Building  All GHG
# 2672  ZWE     Zimbabwe  Climate Watch  Manufacturing/Construction  All GHG
# 2673  ZWE     Zimbabwe  Climate Watch              Transportation  All GHG
# 2674  ZWE     Zimbabwe  Climate Watch       Other Fuel Combustion  All GHG
# 2675  ZWE     Zimbabwe  Climate Watch          Fugitive Emissions  All GHG
#
# ...

# %%
Countries = ['Afghanistan']
k = 'Afghanistan'
for i in range(2676):
    if k != GHG_data_pre["Country"][i]:
        k = GHG_data_pre["Country"][i]
        Countries.append(k)
A = []
for i in range(195):
    Data = GHG_data_pre[GHG_data_pre["Country"] == Countries[i]].iloc[:,6:39].sum()
    A.append(Data)
A
# Out:
# [2022    102.21
#  2021    102.79
#  2020    107.85
#  2019    104.41
#  2018    103.52
#  2017     99.18
#  2016     96.44
#  2015     99.33
#  2014     98.49
#  2013     97.84
#  2012    101.16
#  2011    108.91
#  2010     94.79
#  2009     79.79
#  2008     69.31
#  2007     58.81
#  2006     56.01
#  2005     54.31
#  2004     49.87
#  2003     51.42
#  2002     48.79
#  2001     39.94
#  2000     40.51
#  1999     46.27
#  1998     43.55
#  1997     40.96
#  1996     37.96
#  1995     34.64
#  1994     33.43
#  1993     33.03
#  1992     32.23
#  1991     34.14
#  1990     40.25
#  dtype: float64,
#  2022    426.81
#  2021    427.74
#  2020    418.45
#  2019    463.81
#  2018    444.08
#  2017    493.85
#  2016    502.49
#  2015    514.86
#  2014    489.89
#  2013    488.17
#  2012    479.38
#  2011    476.32
#  2010    478.81
#  2009    460.52
#  2008    455.52
#  2007    431.47
#  2006    402.04
#  2005    403.07
#  2004    392.49
#  2003    376.63
#  2002    357.18
# ...
